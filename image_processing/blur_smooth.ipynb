# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../images/car5.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img,cmap='gray')

# %% [markdown]
# ## Gamma correction

# %%
gamma = 1/4 # < 1 for brighter, for darker > 1
# np.power(img,gamma)
# Out:
# array([[255, 255, 255, ..., 149, 156, 136],
#        [255, 255, 255, ..., 151, 156, 137],
#        [255, 255, 255, ..., 149, 155, 139],
#        ...,
#        [ 62,  64,  66, ..., 103, 104, 106],
#        [ 68,  69,  71, ..., 107, 107, 108],
#        [ 63,  66,  69, ..., 111, 110, 107]], dtype=uint8)

# %%
blurred_img = cv2.medianBlur(img,5)

# %%
plt.imshow(blurred_img, cmap='gray')
