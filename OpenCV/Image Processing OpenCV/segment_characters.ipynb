# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread('../images/license2.jpg')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
cv2.rectangle(image,(1600,700),(1800,1900),(0,255,0),20)
# Out:
# array([[[ 35,  42,  50],
#         [ 33,  40,  48],
#         [ 33,  40,  48],
#         ...,
#         [ 19,  20,  25],
#         [ 20,  21,  26],
#         [ 23,  24,  29]],
#
#        [[ 31,  38,  46],
#         [ 31,  38,  46],
#         [ 30,  37,  45],
#         ...,
#         [ 21,  22,  27],
#         [ 21,  22,  27],
#         [ 22,  23,  28]],
#
#        [[ 32,  39,  47],
#         [ 32,  39,  47],
#         [ 31,  38,  46],
#         ...,
#         [ 22,  23,  28],
#         [ 22,  23,  28],
#         [ 21,  22,  27]],
#
#        ...,
#
#        [[ 72, 108, 144],
#         [ 73, 109, 145],
#         [ 71, 107, 143],
#         ...,
#         [ 77, 107, 141],
#         [ 76, 106, 140],
#         [ 79, 109, 143]],
#
#        [[ 72, 108, 144],
#         [ 74, 110, 146],
#         [ 72, 108, 144],
#         ...,
#         [ 77, 107, 141],
#         [ 76, 106, 140],
#         [ 79, 109, 143]],
#
#        [[ 71, 107, 143],
#         [ 73, 109, 145],
#         [ 73, 109, 145],
# ...

# %%
plt.imshow(image)
