# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread("../images/license2.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img1, cmap='gray')

# %%
img1
# Out:
# array([[ 41,  39,  39, ...,  20,  21,  24],
#        [ 37,  37,  36, ...,  22,  22,  23],
#        [ 38,  38,  37, ...,  23,  23,  22],
#        ...,
#        [101, 102, 100, ..., 102, 101, 104],
#        [101, 103, 101, ..., 102, 101, 104],
#        [100, 102, 102, ..., 103, 101, 103]], dtype=uint8)

# %%
ret, thresh = cv2.threshold(img1, 160, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(thresh, cmap='gray')
