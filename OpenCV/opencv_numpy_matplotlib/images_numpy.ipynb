# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('./images/car1.jpg') # path to the image

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (640, 640, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_arr.shape
# Out:
# (640, 640, 3)

# %%
# red channel values
red = pic_red[:,:,0]
plt.imshow(red, cmap='gray') # red channel only

# %%
plt.imshow(pic_arr[:,:,1], cmap='gray') # green channel only

# %%
plt.imshow(pic_arr[:,:,2], cmap='gray') #  blue channel

# %%
pic_red[:,:,1] = 0 # removing all the green channels
plt.imshow(pic_red)

# %%
pic_red[:,:,2] = 0 # removing all the blue channel
plt.imshow(pic_red)

# %%
pic_red[:,:,0] = 0 # removing the red channel also now all 3 channels have 0 value
plt.imshow(pic_red)

# %%
pic_red[:,:,2] = 255 # making only the image blue
plt.imshow(pic_red)
